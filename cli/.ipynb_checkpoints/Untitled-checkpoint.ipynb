# %%
import module namespace p = "http://dgms.io/unity/modules/visualization/plotting";

import module namespace m = "http://www.w3.org/2005/xpath-functions/math";

p:plot2d({
    
    plots: [
        {

            data:
            [
                {
                    style: "o",
                    mapper: function($x) {$x}
                }
            ]
        }
    ]
})
